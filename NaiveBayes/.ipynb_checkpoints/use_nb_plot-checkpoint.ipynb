# %% [markdown]
# # Retrain with same articles in each window

# %%
from NaiveBayes import NaiveBayes
import json
import numpy

def use_nb_indiv(datas_train, datas_valid, reTrain = 0):
    # reTrain = 0: no retrain
    #           1: use true to retrain
    #           2: use predict to retrain
    # The Naive Bayes Model
    nb = NaiveBayes()
    # Record all of the predictions
    predicts_all = []
    # Number of all of the correctly predicted articles
    correct_all = 0
    # Correctly predicted ratio in each part
    correct_ratios = []
    # First and only train if reTrain == 0
    if reTrain == 0:
        nb.train(datas_train)
    for cur_part in range(1,partition+1):
        # If no retrain
        if reTrain in [1, 2]:
            nb.train(datas_train)
        # All of the predictions in this part
        predicts = [nb.predict(data['content'])[0] for data in datas_valid]
        # Append to all of the predictions
        predicts_all += predicts
        # Number of correctly predicted articles in this part
        correct = 0
        for i in range(len(predicts)):
            if predicts[i] == datas_valid[i]['category']:
                correct += 1
        # Add to all of the correctly predicted articles
        correct_all += correct
        # Add to all of the ratios
        correct_ratios.append(correct/len(datas_valid))
        print("Correct: ", correct, "out of ", len(datas_valid))
        print(datas_valid[-1]['date'])
        # get next train, valid pair
        datas_train = datas[min(len(datas), plen*cur_part) : min(len(datas), plen*(cur_part+1))]
        datas_valid = datas[min(len(datas), plen*(cur_part+1)) : min(len(datas), plen*(cur_part+2))]
        # Update data_train only if use predict to retrain
        if reTrain == 2:
            for i in range(len(datas_train)):
                datas_train[i]['category'] = predicts[i]
    #
    res = "Correct: %d out of %d"%(correct_all, len(predicts_all))
    print(res)
    return correct_ratios
    #return res

# %% [markdown]
# ## retrain performance with random order

# %%
# %%capture
with open('../datas/bbc_preprocessed.json') as f:
    datas = json.load(f)

import random
random.seed(5220)
random.shuffle(datas)

partition = 100
plen = len(datas)//partition
d1 = datas[:plen]
d2 = datas[plen:plen*2]

# no retrain
res1 = use_nb_indiv(d1, d2, reTrain = 0)
# use true to retrain
res2 = use_nb_indiv(d1, d2, reTrain = 1)
# use predict to retrain
res3 = use_nb_indiv(d1, d2, reTrain = 2)

# %%
import matplotlib.pyplot as plt

# %%
no_retrain_line,           = plt.plot(list(range(len(res1))), res1, label = 'no retrain', color = 'green')
retrain_with_true_line,    = plt.plot(list(range(len(res2))), res2, label = 'retrain with true', color = 'blue')
retrain_with_predict_line, = plt.plot(list(range(len(res2))), res3, label = 'retrain with predict', color = 'orange')
plt.legend(handles = [no_retrain_line, retrain_with_true_line, retrain_with_predict_line])
plt.show()

# %% [markdown]
# ## retrain performance with timeseries order

# %%
# %%capture
with open('../datas/bbc_preprocessed.json') as f:
    datas = json.load(f)

partition = 100
plen = len(datas)//partition
d1 = datas[:plen]
d2 = datas[plen:plen*2]

# no retrain
res1 = use_nb_indiv(d1, d2, reTrain = 0)
# use true to retrain
res2 = use_nb_indiv(d1, d2, reTrain = 1)
# use predict to retrain
res3 = use_nb_indiv(d1, d2, reTrain = 2)

# %%
no_retrain_line,           = plt.plot(list(range(len(res1))), res1, label = 'no retrain', color = 'green')
retrain_with_true_line,    = plt.plot(list(range(len(res2))), res2, label = 'retrain with true', color = 'blue')
retrain_with_predict_line, = plt.plot(list(range(len(res2))), res3, label = 'retrain with predict', color = 'orange')
plt.legend(handles = [no_retrain_line, retrain_with_true_line, retrain_with_predict_line])
plt.show()

# %% [markdown]
# # Retrain with same time interval in each window

# %%
with open('../datas/bbc_classifyTimeSeries.json') as f:
    datasss = json.load(f)

# %%
import datetime
def to_datetime(date):
    return datetime.datetime.strptime(date , '%d %B %Y')

for datass in datasss:
    date  = datass['date']
    datas = datass['datas']
    
    datass['date'] = to_datetime(date)
    for data in datas:
        data['date'] = to_datetime(data['date'])

# %% [markdown]
# ## time interval: 30 days

# %%
from dateutil import relativedelta
init_date = datasss[0]['date']
datasss_30_day = []
interval = 30
datediff = relativedelta.relativedelta(days = interval)

cur_date = init_date
for datass in datasss:
    date = datass['date']
    datas = datass['datas']
    if date < cur_date:
        datasss_30_day[-1] += (datas)
    else:
        datasss_30_day.append(datas)
        cur_date = cur_date + datediff

# %% [markdown]
# ### Number of articles in each intervals

# %%
datasss_30_day_cnt = [len(datass) for datass in datasss_30_day]

# %%
plt.plot(list(range(len(datasss_30_day_cnt))), datasss_30_day_cnt)
plt.show()

# %%
datasss_30_day_cnt = [len(datass) for datass in datasss_30_day][20:]

# %%
plt.plot(list(range(len(datasss_30_day_cnt))), datasss_30_day_cnt)
plt.show()

# %%
# The Naive Bayes Model
nb = NaiveBayes()
# Record all of the predictions
predicts_all = []
# Number of all of the correctly predicted articles
correct_all = 0
# Correctly predicted ratio in each part
correct_ratios = []
# First train, if reTrain = False, only train

datasss_x = datasss_30_day
for index in range(len(dasss_x)-1):
    datas_train = datasss_x[i]
    datas_valid = datasss_x[i+1]
    
    nb.train(data_s_train)
    
    # All of the predictions in this part
    predicts = [nb.predict(data['content'])[0] for data in datas_valid]
    # Append to all of the predictions
    predicts_all += predicts
    # Number of correctly predicted articles in this part
    correct = 0
    for i in range(len(predicts)):
        if predicts[i] == datas_valid[i]['category']:
            correct += 1
    # Add to all of the correctly predicted articles
    correct_all += correct
    # Add to all of the ratios
    correct_ratios.append(correct/len(datas_valid))
    print("Correct: ", correct, "out of ", len(datas_valid))
    print(datas_valid[-1]['date'])
    #

# %%
datasss_30_day[0]
# Out:
# [[{'category': 'Health',
#    'content': ['A',
#     'woman',
#     'bodi',
#     'shape',
#     'influenc',
#     'good',
#     'memori',
#     'US',
#     'research',
#     'carri',
#     'excess',
#     'weight',
#     'impair',
#     'older',
#     'women',
#     'brain',
#     'carri',
#     'hip',
#     'make',
#     'matter',
#     'wors',
#     'northwestern',
#     'medicin',
#     'team',
#     'found',
#     'appl',
#     'shape',
#     'women',
#     'fare',
#     'pear',
#     'cognit',
#     'test',
#     'deposit',
#     'fat',
#     'waist',
#     'increas',
#     'risk',
#     'cancer',
#     'diabet',
#     'heart',
#     'diseas',
#     'expert',
#     'warn',
#     'find',
#     'journal',
#     'american',
#     'geriatr',
#     'societi',
#     'highlight',
#     'import',
#     'maintain',
#     'healthi',
#     'weight',
#     'bodi',
#     'mind',
#     'health',
#     'risk',
#     'obes',
#     'vascular',
#     'diseas',
#     'inflamm',
#     'explain',
#     'peopl',
#     'overweight',
#     'higher',
#     'risk',
#     'dementia',
#     'latest',
#     'studi',
#     'suggest',
#     'bit',
#     'extra',
#     'fat',
#     'waist',
#     'protect',
#     'brain',
#     'function',
#     'research',
#     'belli',
#     'fat',
#     'make',
#     'femal',
#     'hormon',
#     'oestrogen',
#     'natur',
#     'dip',
#     'menopaus',
#     'oestrogen',
#     'thought',
#     'protect',
#     'brain',
#     'cognit',
#     'declin',
#     'studi',
#     'involv',
#     'post',
#     'menopaus',
#     'women',
#     'age',
#     'women',
#     'complet',
#     'memori',
#     'test',
#     'doctor',
#     'judg',
#     'brain',
#     'function',
#     'weigh',
#     'measur',
#     'score',
#     'obes',
#     'scale',
#     'bodi',
#     'mass',
#     'index',
#     'bmi',
#     'women',
#     'overweight',
#     'obes',
#     'research',
#     'found',
#     'point',
#     'increas',
#     'woman',
#     'bmi',
#     'memori',
#     'score',
#     'drop',
#     'point',
#     'pear',
#     'shape',
#     'women',
#     'smaller',
#     'waist',
#     'bigger',
#     'hip',
#     'score',
#     'poorli',
#     'research',
#     'relat',
#     'type',
#     'fat',
#     'deposit',
#     'hip',
#     'versu',
#     'waist',
#     'scientist',
#     'kind',
#     'fat',
#     'releas',
#     'hormon',
#     'vari',
#     'effect',
#     'insulin',
#     'resist',
#     'lipid',
#     'blood',
#     'pressur',
#     'lead',
#     'research',
#     'Dr',
#     'diana',
#     'kerwin',
#     'We',
#     'find',
#     'kind',
#     'fat',
#     'detriment',
#     'affect',
#     'brain',
#     'function',
#     'fat',
#     'contribut',
#     'format',
#     'plaqu',
#     'alzheim',
#     'diseas',
#     'restrict',
#     'blood',
#     'flow',
#     'brain',
#     'rebecca',
#     'wood',
#     'chief',
#     'execut',
#     'alzheim',
#     'research',
#     'trust',
#     'pear',
#     'shape',
#     'incred',
#     'common',
#     'studi',
#     'doesn',
#     'explain',
#     'fulli',
#     'link',
#     'bodi',
#     'shape',
#     'brain',
#     'function',
#     'make',
#     'case',
#     'watch',
#     'scale',
#     'natur',
#     'bodi',
#     'shape',
#     'lot',
#     'weight',
#     'evid',
#     'danger',
#     'obes',
#     'lifestyl',
#     'weight',
#     'check'],
#    'date': datetime.datetime(2010, 7, 14, 0, 0),
#    'title': ['big', 'hip', 'impair', 'women', 'memori', 'studi', 'find'],
#    'url': 'http://www.bbc.com/news/health-10614837'}],
#  [{'category': 'Technology',
#    'content': ['game',
#     'industri',
#     'govern',
#     'decis',
#     'award',
#     'tax',
#     'break',
#     'premis',
#     'sector',
#     'tax',
#     'relief',
#     'float',
#     'labour',
#     'govern',
#     'elect',
#     'cultur',
#     'minist',
#     'Ed',
#     'vaizey',
#     'told',
#     'deleg',
#     'video',
#     'game',
#     'develop',
#     'confer',
#     'brighton',
#     'case',
#     'made',
#     'Dr',
#     'richard',
#     'wilson',
#     'chief',
#     'execut',
#     'offic',
#     'game',
#     'trade',
#     'tiga',
#     'told',
#     'bbc',
#     'disappoint',
#     'We',
#     'made',
#     'convinc',
#     'case',
#     'previou',
#     'govern',
#     'conserv',
#     'parti',
#     'lib',
#     'dem',
#     'support',
#     'tax',
#     'relief',
#     'parliament',
#     'We',
#     'convinc',
#     'point',
#     'essenti',
#     'conserv',
#     'parti',
#     'georg',
#     'osborn',
#     'reneg',
#     'promis',
#     'It',
#     'hard',
#     'feel',
#     'ad',
#     'drive',
#     'forc',
#     'game',
#     'industri',
#     'push',
#     'tax',
#     'relief',
#     'lower',
#     'bottom',
#     'line',
#     'compet',
#     'gener',
#     'packag',
#     'offer',
#     'countri',
#     'attempt',
#     'attract',
#     'develop',
#     'studio',
#     'canada',
#     'offer',
#     'signific',
#     'tax',
#     'break',
#     'case',
#     'worth',
#     'encourag',
#     'growth',
#     'game',
#     'sector',
#     'major',
#     'factor',
#     'knock',
#     'UK',
#     '3rd',
#     '5th',
#     'largest',
#     'global',
#     'develop',
#     'comput',
#     'game',
#     'speak',
#     'bbc',
#     'Mr',
#     'vaizey',
#     'peopl',
#     'avoid',
#     'council',
#     'despair',
#     'canada',
#     'attract',
#     'countri',
#     'enorm',
#     'attract',
#     'huge',
#     'rang',
#     'talent',
#     'countri',
#     'massiv',
#     'pull',
#     'game',
#     'develop',
#     'time',
#     'Mr',
#     'vaizey',
#     'spoken',
#     'publicli',
#     'subject',
#     'acknowledg',
#     'topic',
#     'face',
#     'audienc',
#     'hostil',
#     'point',
#     'view',
#     'understood',
#     'video',
#     'game',
#     'industri',
#     'disappoint',
#     'rule',
#     'game',
#     'industri',
#     'tax',
#     'break',
#     'futur',
#     'opportun',
#     'decis',
#     'form',
#     'committe',
#     'review',
#     'tax',
#     'situat',
#     'game',
#     'industri',
#     'tax',
#     'relief',
#     'nichola',
#     'lovel',
#     'busi',
#     'analyst',
#     'game',
#     'sector',
#     'told',
#     'bbc',
#     'tax',
#     'relief',
#     'stifl',
#     'develop',
#     'creativ',
#     'If',
#     'canada',
#     'tax',
#     'break',
#     'afford',
#     'end',
#     'battl',
#     'spend',
#     'compet',
#     'We',
#     'shouldn',
#     'compet',
#     'term',
#     'britain',
#     'creativ',
#     'expertis',
#     'great',
#     'univers',
#     'develop',
#     'busi',
#     'model',
#     'tax',
#     'break',
#     'easier',
#     'larg',
#     'establish',
#     'compani',
#     'exploit',
#     'firm',
#     'tap',
#     'smaller',
#     'firm',
#     'bigger',
#     'end',
#     'build',
#     'busi',
#     'model',
#     'round',
#     'tax',
#     'break',
#     'explor',
#     'opportun',
#     'ad',
#     'In',
#     'interview',
#     'bbc',
#     'E3',
#     'expo',
#     'lo',
#     'angel',
#     'june',
#     'yve',
#     'guillemot',
#     'chief',
#     'execut',
#     'ubisoft',
#     'europ',
#     'largest',
#     'video',
#     'game',
#     'publish',
#     'incent',
#     'firm',
#     'risk',
#     'good',
#     'month',
#     'pound',
#     'cost',
#     'creat',
#     'game',
#     'Mr',
#     'guillemot',
#     'cost',
#     'high',
#     'rise',
#     'pound',
#     'due',
#     'part',
#     'fall',
#     'US',
#     'dollar',
#     'euro',
#     'make',
#     'britain',
#     'expens',
#     'term',
#     'staff',
#     'export',
#     'cost',
#     'georg',
#     'osborn',
#     'exchang',
#     'rate',
#     'pound',
#     'Mr',
#     'vaizey',
#     'told',
#     'bbc',
#     'currenc',
#     'healthi',
#     'economi',
#     'agre',
#     'balanc',
#     'struck',
#     'cost',
#     'export',
#     'good',
#     'ad',
#     'month',
#     'nintendo',
#     'compani',
#     'presid',
#     'satoru',
#     'iwata',
#     'told',
#     'bbc',
#     'ongo',
#     'currenc',
#     'gyrat',
#     'signific',
#     'effect',
#     'profit',
#     'perspect',
#     'global',
#     'economi',
#     'stabilis',
#     'uncertainti',
#     'estim',
#     'profit',
#     'told',
#     'bbc',
#     'Mr',
#     'iwata',
#     'govern',
#     'bring',
#     'ongo',
#     'currenc',
#     'fluctuat',
#     'control'],
#    'date': datetime.datetime(2010, 7, 15, 0, 0),
#    'title': ['govern', 'video', 'game', 'develop', 'UK'],
#    'url': 'http://www.bbc.com/news/technology-10651378'},
#   {'category': 'Technology',
#    'content': ['internet',
#     'great',
#     'level',
#     'thought',
#     'harvard',
#     'academ',
#     'ethan',
#     'zuckerman',
#     'Mr',
#     'zuckerman',
#     'speak',
#     'ted',
#     'global',
#     'technolog',
#     'entertain',
#     'design',
#     'confer',
#     'oxford',
#     'He',
#     'web',
#     'contrari',
#     'origin',
#     'utopian',
#     'vision',
#     'user',
#     'focus',
#     'inform',
#     'hand',
#     'wealthi',
#     'countri',
#     'It',
#     'make',
#     'imaginari',
#     'cosmopolitan',
#     'told',
#     'deleg',
#     'social',
#     'network',
#     'made',
#     'problem',
#     'wors',
#     'major',
#     'peopl',
#     'share',
#     'inform',
#     'folk',
#     'share',
#     'world',
#     'view',
#     'We',
#     'broad',
#     'view',
#     'world',
#     'televis',
#     'newspap',
#     'internet',
#     'vastli',
#     'wider',
#     'pictur',
#     'parent',
#     'grandpar',
#     'world',
#     'view',
#     'narrow',
#     'Mr',
#     'zuckerman',
#     'entrepreneur',
#     'blogger',
#     'research',
#     'harvard',
#     'berkman',
#     'center',
#     'internet',
#     'societi',
#     'aim',
#     'situat',
#     'realis',
#     'origin',
#     'vision',
#     'net',
#     'He',
#     'point',
#     'research',
#     'show',
#     'focu',
#     'media',
#     'organis',
#     'narrow',
#     'recent',
#     'year',
#     'grow',
#     'US',
#     'averag',
#     'nightli',
#     'newscast',
#     'focus',
#     'intern',
#     'stori',
#     'told',
#     'audienc',
#     'percentag',
#     'intern',
#     'news',
#     'averag',
#     'newscast',
#     'He',
#     'internet',
#     'global',
#     'reach',
#     'infrastructur',
#     'address',
#     'gap',
#     'peopl',
#     'chose',
#     'engag',
#     'promis',
#     'internet',
#     'idea',
#     'click',
#     'britain',
#     'read',
#     'newspap',
#     'australia',
#     'india',
#     'nigeria',
#     'ghana',
#     'canada',
#     'cost',
#     'end',
#     'wider',
#     'view',
#     'world',
#     'truth',
#     'averag',
#     'won',
#     'He',
#     'UK',
#     'traffic',
#     'popular',
#     'news',
#     'site',
#     'domest',
#     'site',
#     'pattern',
#     'world',
#     'US',
#     'news',
#     'focus',
#     'north',
#     'america',
#     'countri',
#     'iraq',
#     'afghanistan',
#     'troop',
#     'base',
#     'problem',
#     'compound',
#     'social',
#     'network',
#     'tool',
#     'twitter',
#     'trap',
#     'peopl',
#     'call',
#     'filter',
#     'bubbl',
#     'phrase',
#     'put',
#     'forward',
#     'polit',
#     'activist',
#     'eli',
#     'paris',
#     'internet',
#     'big',
#     'understand',
#     'pictur',
#     'similar',
#     'friend',
#     'Mr',
#     'zuckerman',
#     'If',
#     'turn',
#     'friend',
#     'eventu',
#     'wisdom',
#     'flock',
#     'He',
#     'highlight',
#     'research',
#     'twitter',
#     'found',
#     'quarter',
#     'US',
#     'user',
#     'african',
#     'american',
#     'pretti',
#     'surpris',
#     'american',
#     'user',
#     'assum',
#     'twitter',
#     'nerdi',
#     'white',
#     'guy',
#     'research',
#     'scientist',
#     'tech',
#     'giant',
#     'ibm',
#     'shown',
#     'popular',
#     'topic',
#     'convers',
#     'white',
#     'user',
#     'african',
#     'american',
#     'user',
#     'highlight',
#     'fact',
#     'network',
#     'reinforc',
#     'world',
#     'view',
#     'cookout',
#     'term',
#     'black',
#     'twitter',
#     'user',
#     'whilst',
#     'oil',
#     'spill',
#     'predominantli',
#     'white',
#     'topic',
#     'wider',
#     'world',
#     'click',
#     'filter',
#     'Mr',
#     'zuckerman',
#     'Mr',
#     'zuckerman',
#     'solut',
#     'realis',
#     'origin',
#     'vision',
#     'internet',
#     'contribut',
#     'greater',
#     'understand',
#     'wider',
#     'world',
#     'Of',
#     'find',
#     'mechan',
#     'amplifi',
#     'voic',
#     'thousand',
#     'blogger',
#     'countri',
#     'repres',
#     'mainstream',
#     'media',
#     'Mr',
#     'zuckerman',
#     'admit',
#     'interest',
#     'founder',
#     'profit',
#     'network',
#     'blogger',
#     'call',
#     'global',
#     'voic',
#     'aim',
#     'fill',
#     'gap',
#     'global',
#     'media',
#     'coverag',
#     'network',
#     'hidden',
#     'wider',
#     'world',
#     'time',
#     'crisi',
#     'network',
#     'madagascan',
#     'blogger',
#     'call',
#     'foko',
#     'club',
#     'origin',
#     'set',
#     'teach',
#     'high',
#     'school',
#     'student',
#     'english',
#     'suddenli',
#     'rose',
#     'promin',
#     'presid',
#     'countri',
#     'overthrown',
#     'media',
#     'organis',
#     'bar',
#     'countri',
#     'foko',
#     'report',
#     'break',
#     'news',
#     'blog',
#     'cellphon',
#     'camera',
#     'If',
#     'wider',
#     'world',
#     'find',
#     'rais',
#     'voic',
#     'don',
#     'hear',
#     'madagascar',
#     'He',
#     'highlight',
#     'project',
#     'china',
#     'call',
#     'yeeyan',
#     'network',
#     'volunt',
#     'translat',
#     'publish',
#     'articl',
#     'day',
#     'western',
#     'public',
#     'york',
#     'time',
#     'english',
#     'languag',
#     'version',
#     'insight',
#     'chines',
#     'media',
#     'realis',
#     'vision',
#     'peopl',
#     'curat',
#     'collect',
#     'content',
#     'bridg',
#     'cultur',
#     'put',
#     'content',
#     'context',
#     'bridg',
#     'figur',
#     'xenophil',
#     'act',
#     'trust',
#     'guid',
#     'unfamiliar',
#     'content',
#     'My',
#     'challeng',
#     'make',
#     'person',
#     'decis',
#     'wider',
#     'world',
#     'We',
#     'figur',
#     'rewir',
#     'system',
#     'We',
#     'fix',
#     'media',
#     'fix',
#     'internet',
#     'fix',
#     'educ',
#     'In',
#     'addit',
#     'net',
#     'translat',
#     'project',
#     'tool',
#     'mechan',
#     'discov',
#     'content',
#     'serendip',
#     'ted',
#     'global',
#     'run',
#     'juli',
#     'oxford',
#     'UK'],
#    'date': datetime.datetime(2010, 7, 15, 0, 0),
#    'title': ['internet', 'great', 'level'],
#    'url': 'http://www.bbc.com/news/technology-10642697'},
#   {'category': 'Technology',
#    'content': ['britain',
#     'magazin',
#     'dedic',
#     'PC',
#     'game',
#     'ceas',
#     'public',
#     'year',
#     'PC',
#     'zone',
#     'magazin',
#     'anarch',
#     'irrever',
#     'monthli',
#     'journal',
#     'set',
#     'close',
#     'issu',
#     'septemb',
#     'futur',
#     'publish',
#     'titl',
#     'closur',
#     'wake',
#     'strateg',
#     'review',
#     'PC',
#     'game',
#     'portfolioat',
#     'audit',
#     'PC',
#     'zone',
#     'sell',
#     'copi',
#     'month',
#     'magazin',
#     'start',
#     'life',
#     'dank',
#     'dusti',
#     'basement',
#     'central',
#     'london',
#     'It',
#     'rose',
#     'ash',
#     'monthli',
#     'multi',
#     'format',
#     'game',
#     'magazin',
#     'PC',
#     'zone',
#     'full',
#     'beat',
#     'humour',
#     'adolesc',
#     'joke',
#     'occas',
#     'court',
#     'controversi',
#     'close',
#     'octob',
#     'staff',
#     'retain',
#     'form',
#     'core',
#     'staff',
#     'singl',
#     'format',
#     'magazin',
#     'PC',
#     'zone',
#     'concept',
#     'PC',
#     'game',
#     'earli',
#     'game',
#     'tradit',
#     'publish',
#     'dedic',
#     'game',
#     'consol',
#     'sega',
#     'mega',
#     'drive',
#     'super',
#     'nintendo',
#     'entertain',
#     'system',
#     'sne',
#     'legaci',
#     'gener',
#     'micro',
#     'comput',
#     'renegad',
#     'PR',
#     'tim',
#     'pont',
#     'publish',
#     'magazin',
#     'issu',
#     'told',
#     'bbc',
#     'publish',
#     'perceiv',
#     'mad',
#     'At',
#     'time',
#     'receiv',
#     'wisdom',
#     'buy',
#     'huge',
#     'success',
#     'humour',
#     'legaci',
#     'left',
#     'magazin',
#     'It',
#     'public',
#     'schoolboy',
#     'clever',
#     'holier',
#     'work',
#     'ad',
#     'issu',
#     'decis',
#     'free',
#     'CD',
#     'rom',
#     'issu',
#     'full',
#     'game',
#     'demo',
#     'At',
#     'time',
#     'internet',
#     'infanc',
#     'gamer',
#     'hand',
#     'massiv',
#     'step',
#     'magazin',
#     'tradit',
#     'floppi',
#     'disk',
#     '5mb',
#     'data',
#     'CD',
#     'rom',
#     '650mb',
#     'space',
#     'meant',
#     'creat',
#     'role',
#     'unheard',
#     'magazin',
#     'publish',
#     'time',
#     'disk',
#     'editor',
#     'step',
#     'journal',
#     'join',
#     'bbc',
#     'massiv',
#     'learn',
#     'curv',
#     'thing',
#     'swimmingli',
#     'At',
#     'year',
#     'format',
#     'magazin',
#     'significantli',
#     'appoint',
#     'editor',
#     'john',
#     'davison',
#     'He',
#     'younger',
#     'He',
#     'game',
#     'previou',
#     'editor',
#     'humour',
#     'Mr',
#     'pont',
#     'style',
#     'magazin',
#     'slew',
#     'writer',
#     'onboard',
#     'magazin',
#     'develop',
#     'life',
#     'charli',
#     'brooker',
#     'fresh',
#     'polytechn',
#     'initi',
#     'work',
#     'magazin',
#     'produc',
#     'occasion',
#     'game',
#     'orient',
#     'cartoon',
#     'thought',
#     'qualifi',
#     'writer',
#     'told',
#     'bbc',
#     'david',
#     'mccandless',
#     'writer',
#     'PC',
#     'zone',
#     'suggest',
#     'write',
#     'rest',
#     'histori',
#     'PC',
#     'zone',
#     'learnt',
#     'write',
#     'page',
#     'review',
#     'abstract',
#     'game',
#     'end',
#     'fill',
#     'pueril',
#     'joke',
#     'snideway',
#     'world',
#     'ad',
#     'magazin',
#     'enjoy',
#     'record',
#     'sale',
#     'stumbl',
#     'My',
#     'faux',
#     'pa',
#     'extraordinair',
#     'occur',
#     'made',
#     'CD',
#     'rom',
#     'fill',
#     'thousand',
#     'doom',
#     'level',
#     'download',
#     'internet',
#     'doom',
#     'biggest',
#     'sell',
#     'PC',
#     'game',
#     'point',
#     'time',
#     'easi',
#     'user',
#     'creat',
#     'custom',
#     'level',
#     'troubl',
#     'download',
#     'fill',
#     'CD',
#     'rom',
#     'day',
#     'slow',
#     'dial',
#     'modem',
#     'meant',
#     'wasn',
#     'chanc',
#     'check',
#     'level',
#     'put',
#     'disk',
#     'hundr',
#     'nineti',
#     'level',
#     'fine',
#     'adult',
#     'content',
#     'sort',
#     'thing',
#     'magazin',
#     'aim',
#     'teenag',
#     'charli',
#     'brooker',
#     'cropper',
#     'biggest',
#     'game',
#     'time',
#     'tomb',
#     'raider',
#     'heroin',
#     'lara',
#     'croft',
#     'battl',
#     'hundr',
#     'anim',
#     'Mr',
#     'brooker',
#     'creat',
#     'cartoon',
#     'parodi',
#     'game',
#     'It',
#     'mock',
#     'advert',
#     'zoo',
#     'encourag',
#     'peopl',
#     'kill',
#     'anim',
#     'It',
#     'base',
#     'lara',
#     'worri',
#     'annoy',
#     'eido',
#     'game',
#     'publish',
#     'pull',
#     'part',
#     'end',
#     'result',
#     'poor',
#     'tast',
#     'cartoon',
#     'featur',
#     'young',
#     'boy',
#     'beat',
#     'monkey',
#     'round',
#     'head',
#     'claw',
#     'hammer',
#     'tim',
#     'pont',
#     'lowest',
#     'point',
#     'stewardship',
#     'magazin',
#     'On',
#     'occas',
#     'magazin',
#     'pull',
#     'shelv',
#     'iron',
#     'twist',
#     'remain',
#     'sell',
#     'issu',
#     'time',
#     'magazin',
#     'ride',
#     'wave',
#     'laddish',
#     'humour',
#     'sale',
#     'time',
#     'high',
#     'explos',
#     'internet',
#     'dot',
#     'crash',
#     'spelt',
#     'end',
#     'call',
#     'golden',
#     'time',
#     'sale',
#     'magazin',
#     'start',
#     'slow',
#     'declin',
#     'staff',
#     'start',
#     'drift',
#     'pueril',
#     'humour',
#     'longer',
#     'vogu',
#     'In',
#     'magazin',
#     'sold',
#     'futur',
#     'publish',
#     'impos',
#     'stricter',
#     'budgetari',
#     'control',
#     'brought',
#     'staff',
#     'redesign',
#     'magazin',
#     'event',
#     'toll',
#     'internet',
#     'speed',
#     'increas',
#     'dramat',
#     'earli',
#     'day',
#     'dial',
#     'modem',
#     'consol',
#     'market',
#     'explod',
#     'releas',
#     'playstat',
#     'xbox',
#     'slew',
#     'game',
#     'websit',
#     'sprung',
#     'peopl',
#     'game',
#     'demo',
#     'review',
#     'click',
#     'mous',
#     'wait',
#     'fix',
#     'month',
#     'magazin',
#     'circul',
#     'continu',
#     'declin',
#     'industri',
#     'expert',
#     'express',
#     'surpris',
#     'magazin',
#     'long',
#     'closur',
#     'PC',
#     'zone',
#     'end',
#     'era',
#     'Mr',
#     'brooker',
#     'write',
#     'mid',
#     'peopl',
#     'buy',
#     'mag',
#     'basi',
#     'CD',
#     'net',
#     'growth',
#     'consol',
#     'assail',
#     'front',
#     'game',
#     'play',
#     'consol',
#     'So',
#     'support',
#     'die',
#     'game',
#     'format',
#     'die',
#     'media',
#     'format',
#     'It',
#     'shame',
#     'inevit',
#     'ad',
#     'richard',
#     'shoemak',
#     'deputi',
#     'editor',
#     'PC',
#     'zone',
#     'PC',
#     'game',
#     'magazin',
#     'publish',
#     'dead',
#     'PC',
#     'game',
#     'sold',
#     'digit',
#     'distribut',
#     'peopl',
#     'steam',
#     'don',
#     'sell',
#     'activis',
#     'world',
#     'warcraft',
#     'biggest',
#     'titl',
#     'playabl',
#     'PC',
#     'nich',
#     'magazin',
#     'develop',
#     'magazin',
#     'edg',
#     'end',
#     'zone',
#     'sad',
#     'inevit',
#     'It',
#     'pretti',
#     'impress',
#     'long',
#     'In',
#     'statement',
#     'futur',
#     'publish',
#     'consult',
#     'staff',
#     'member',
#     'PC',
#     'zone',
#     'team',
#     'great',
#     'job',
#     'produc',
#     'qualiti',
#     'magazin',
#     'year',
#     'difficult',
#     'decis',
#     'make',
#     'propos',
#     'statement',
#     'read',
#     'strategi',
#     'focu',
#     'market',
#     'leader',
#     'PC',
#     'gamer',
#     'PC',
#     'game',
#     'categori',
#     'issu',
#     'PC',
#     'zone',
#     'due',
#     'sale',
#     'septemb'],
#    'date': datetime.datetime(2010, 7, 15, 0, 0),
#    'title': ['PC', 'zone', 'magazin', 'shut', 'year'],
#    'url': 'http://www.bbc.com/news/technology-10641398'},
#   {'category': 'Technology',
#    'content': ['appl',
#     'call',
#     'surpris',
#     'news',
#     'confer',
#     'juli',
#     'bst',
#     'talk',
#     'iphon',
#     'clamour',
#     'compani',
#     'resolv',
#     'antenna',
#     'problem',
#     'devic',
#     'intensifi',
#     'compani',
#     'refus',
#     'detail',
#     'event',
#     'address',
#     'recept',
#     'problem',
#     'user',
#     'report',
#     'phone',
#     'launch',
#     'month',
#     'appl',
#     'face',
#     'mount',
#     'critic',
#     'analyst',
#     'consum',
#     'handl',
#     'issu',
#     'industri',
#     'watcher',
#     'firm',
#     'danger',
#     'damag',
#     'rock',
#     'star',
#     'reput',
#     'poorli',
#     'dealt',
#     'minor',
#     'problem',
#     'It',
#     'real',
#     'crisi',
#     'leadership',
#     'patrick',
#     'kerley',
#     'senior',
#     'digit',
#     'strategist',
#     'levick',
#     'strateg',
#     'commun',
#     'deal',
#     'crisi',
#     'manag',
#     'reput',
#     'protect',
#     'conflict',
#     'report',
#     'issu',
#     'lot',
#     'confus',
#     'marketplac',
#     'plan',
#     'attack',
#     'today',
#     'compani',
#     'react',
#     'quickli',
#     'chatter',
#     'facebook',
#     'twitter',
#     'turn',
#     'news',
#     'headlin',
#     'case',
#     'Mr',
#     'kerley',
#     'told',
#     'bbc',
#     'view',
#     'echo',
#     'number',
#     'brand',
#     'manag',
#     'industri',
#     'analyst',
#     'handl',
#     'turn',
#     'bigger',
#     'problem',
#     'van',
#     'baker',
#     'senior',
#     'vice',
#     'presid',
#     'research',
#     'gartner',
#     'report',
#     'problem',
#     'iphon',
#     'antenna',
#     'began',
#     'june',
#     'launch',
#     'date',
#     'user',
#     'pre',
#     'order',
#     'phone',
#     'claim',
#     'signal',
#     'strength',
#     'fell',
#     'call',
#     'drop',
#     'grip',
#     'phone',
#     'lower',
#     'left',
#     'side',
#     'post',
#     'video',
#     'youtub',
#     'complain',
#     'recept',
#     'issu',
#     'day',
#     'mail',
#     'purport',
#     'appl',
#     'founder',
#     'steve',
#     'job',
#     'round',
#     'user',
#     'contact',
#     'find',
#     'fix',
#     'problem',
#     'boygeniusreport',
#     'gadget',
#     'news',
#     'blog',
#     'print',
#     'transcript',
#     'Mr',
#     'job',
#     'mail',
#     'back',
#     'work',
#     'day',
#     'rumour',
#     'calm',
#     'authent',
#     'exchang',
#     'deni',
#     'appl',
#     'boygeniu',
#     'maintain',
#     'authent',
#     'controversi',
#     'verac',
#     'light',
#     'fire',
#     'critic',
#     'fan',
#     'alik',
#     'marvel',
#     'tone',
#     'messag',
#     'arrog',
#     'mail',
#     'true',
#     'escal',
#     'problem',
#     'appl',
#     'front',
#     'problem',
#     'deal',
#     'technolog',
#     'analyst',
#     'rob',
#     'enderl',
#     'enderl',
#     'group',
#     'On',
#     'juli',
#     'appl',
#     'issu',
#     'statement',
#     'explain',
#     'surpris',
#     'report',
#     'recept',
#     'problem',
#     'investig',
#     'found',
#     'error',
#     'signal',
#     'bar',
#     'display',
#     'signal',
#     'case',
#     'appl',
#     'latest',
#     'phone',
#     'made',
#     'stainless',
#     'steel',
#     'serv',
#     'antenna',
#     'test',
#     'carri',
#     'week',
#     'consum',
#     'report',
#     'confirm',
#     'problem',
#     'iphon',
#     'recept',
#     'In',
#     'bodi',
#     'blow',
#     'appl',
#     'consum',
#     'report',
#     'recommend',
#     'phone',
#     'user',
#     'flaw',
#     'test',
#     'consum',
#     'report',
#     'iphon',
#     'antenna',
#     'problem',
#     'headlin',
#     'hour',
#     'request',
#     'phone',
#     'recal',
#     'damag',
#     'appl',
#     'bottom',
#     'line',
#     'reput',
#     'appl',
#     'import',
#     'brand',
#     'year',
#     'olivi',
#     'blanchard',
#     'presid',
#     'brand',
#     'builder',
#     'market',
#     'rock',
#     'star',
#     'sens',
#     'fiasco',
#     'iphon',
#     'excus',
#     'attack',
#     'compani',
#     'giant',
#     'year',
#     'ago',
#     'underdog',
#     'issu',
#     'Mr',
#     'blanchard',
#     'told',
#     'bbc',
#     'analyst',
#     'estim',
#     'recal',
#     'cost',
#     '5bn',
#     '1bn',
#     'cost',
#     'issu',
#     'free',
#     'rubber',
#     'bumper',
#     'allevi',
#     'problem',
#     'cheaper',
#     'estim',
#     'base',
#     'retail',
#     'cost',
#     'bumper',
#     'suggest',
#     'protector',
#     'cost',
#     '180m',
#     '118m',
#     'neg',
#     'headlin',
#     'number',
#     'analyst',
#     'report',
#     'consum',
#     'turn',
#     'So',
#     'suppli',
#     'chain',
#     'industri',
#     'check',
#     'build',
#     'plan',
#     'demand',
#     'pattern',
#     'estim',
#     'million',
#     'iphon',
#     'june',
#     'quarter',
#     'million',
#     'shaw',
#     'Wu',
#     'kaufman',
#     'bro',
#     'In',
#     'fact',
#     'sourc',
#     'appl',
#     'difficulti',
#     'strong',
#     'demand',
#     'due',
#     'screen',
#     'suppli',
#     'constraint',
#     'antenna',
#     'issu',
#     'bigger',
#     'deal',
#     'risk',
#     'iphon',
#     'estim'],
#    'date': datetime.datetime(2010, 7, 15, 0, 0),
#    'title': ['appl', 'plan', 'surpris', 'iphon', 'antenna', 'issu'],
#    'url': 'http://www.bbc.com/news/technology-10641910'},
#   {'category': 'Technology',
#    'content': ['cultur',
#     'secretari',
#     'jeremi',
#     'hunt',
#     'blame',
#     'lack',
#     'fund',
#     'govern',
#     'decis',
#     'delay',
#     'roll',
#     'megabit',
#     'broadband',
#     'UK',
#     'previou',
#     'govern',
#     'set',
#     'deadlin',
#     'network',
#     'Mr',
#     'hunt',
#     'suffici',
#     'fund',
#     'meet',
#     'goal',
#     'BT',
#     'warn',
#     'cost',
#     'billion',
#     'fast',
#     'broadband',
#     'part',
#     'britain',
#     'steve',
#     'robertson',
#     'chief',
#     'execut',
#     'BT',
#     'openreach',
#     'told',
#     'bbc',
#     'live',
#     'drive',
#     'programm',
#     'goal',
#     'achiev',
#     '2bn',
#     'public',
#     'fund',
#     'month',
#     'announc',
#     'support',
#     'univers',
#     'servic',
#     'level',
#     'mbp',
#     'minimum',
#     'Mr',
#     'hunt',
#     'industri',
#     'confer',
#     'juli',
#     'provis',
#     'govern',
#     'made',
#     'achiev',
#     'afraid',
#     'convinc',
#     'suffici',
#     'fund',
#     'So',
#     'work',
#     'date',
#     'set',
#     'realist',
#     'target',
#     'achiev',
#     'univers',
#     'mbp',
#     'access',
#     'lifetim',
#     'parliament',
#     'ad',
#     'govern',
#     'industri',
#     'find',
#     'solv',
#     'problem',
#     '175m',
#     'set',
#     'digit',
#     'switchov',
#     'project',
#     'money',
#     'fund',
#     'rollout',
#     'Mr',
#     'hunt',
#     'told',
#     'bbc',
#     'cost',
#     'scope',
#     'confid',
#     'deliv',
#     'commit',
#     'solut',
#     'extens',
#     'superfast',
#     'broadband',
#     'It',
#     'short',
#     'term',
#     'fix',
#     'megabit',
#     'limit',
#     'told',
#     'bbc',
#     'He',
#     'levi',
#     'bbc',
#     'licenc',
#     'fee',
#     'fund',
#     'digit',
#     'switchov',
#     'extend',
#     'Mr',
#     'hunt',
#     'host',
#     'confer',
#     'intend',
#     'mobilis',
#     'compani',
#     'thursday',
#     'tomorrow',
#     'bring',
#     'key',
#     'industri',
#     'player',
#     'deliv',
#     'work',
#     'solut',
#     'make',
#     'ambit',
#     'realiti',
#     'compani',
#     'chanc',
#     'identifi',
#     'barrier',
#     'basic',
#     'level',
#     'broadband',
#     'rural',
#     'area',
#     'suggest',
#     'make',
#     'publicli',
#     'network',
#     'connect',
#     'school',
#     'hospit',
#     'BT',
#     'public',
#     'money',
#     'tune',
#     '2bn',
#     'put',
#     'britain',
#     'top',
#     'super',
#     'fast',
#     'broadband',
#     'leagu',
#     'money',
#     'local',
#     'author',
#     'central',
#     'govern',
#     'european',
#     'union',
#     'telco',
#     'spend',
#     '5bn',
#     'instal',
#     'fast',
#     'broadband',
#     'servic',
#     'UK',
#     'home',
#     'signific',
#     'number',
#     'left',
#     'slow',
#     'lane',
#     'As',
#     'societi',
#     'make',
#     'mind',
#     'essenti',
#     'element',
#     'social',
#     'fabric',
#     'today',
#     'broadband',
#     'make',
#     'peopl',
#     'feel',
#     'depriv',
#     'steve',
#     'robertson',
#     'govern',
#     'conduct',
#     'paper',
#     'trial',
#     'work',
#     'cost',
#     'area',
#     'slow',
#     'broadband',
#     'faster',
#     'servic',
#     'run',
#     'pilot',
#     'area',
#     'cheapest',
#     'option',
#     'emerg',
#     'research',
#     'firm',
#     'point',
#     'topic',
#     'estim',
#     '2m',
#     'home',
#     'unabl',
#     'speed',
#     '2mbp',
#     'remot',
#     'area',
#     'surrey',
#     'villag',
#     'ewhurst',
#     'close',
#     'larg',
#     'town',
#     'data',
#     'neededpoint',
#     'topic',
#     'analyst',
#     'tim',
#     'johnson',
#     'fear',
#     'govern',
#     'work',
#     'hand',
#     'realis',
#     'million',
#     'premis',
#     'defin',
#     'area',
#     'reach',
#     'engin',
#     'servic',
#     'upgrad',
#     'area',
#     'bring',
#     'total',
#     'number',
#     'hous',
#     'upgrad',
#     'closer',
#     'million',
#     'cost',
#     'govern',
#     'danger',
#     'shortag',
#     'money',
#     'search',
#     'clear',
#     'win',
#     'drive',
#     'meg',
#     'minimum',
#     'programm',
#     'concentr',
#     'area',
#     'remot',
#     'A',
#     'smaller',
#     'firm',
#     'rutland',
#     'telecom',
#     'matter',
#     'hand',
#     'rais',
#     'money',
#     'household',
#     'improv',
#     'broadband',
#     'servic',
#     'small',
#     'commun',
#     'process',
#     'made',
#     'harder',
#     'BT',
#     'withhold',
#     'vital',
#     'data',
#     'In',
#     'order',
#     'make',
#     'decis',
#     'cost',
#     'fibr',
#     'commun',
#     'firm',
#     'home',
#     'connect',
#     'green',
#     'street',
#     'cabinet',
#     'rutland',
#     'telecom',
#     'BT',
#     'refus',
#     'hand',
#     'crucial',
#     'data',
#     'BT',
#     'deni',
#     'We',
#     'manual',
#     'process',
#     'advis',
#     'rutland',
#     'telecom',
#     'locat',
#     'street',
#     'cabinet',
#     'ofcom',
#     'confirm',
#     'fulli',
#     'compli',
#     'regulatori',
#     'oblig',
#     'BT',
#     'spokeswoman',
#     'If',
#     'firm',
#     'data',
#     'futur',
#     'offer',
#     'autom',
#     'system',
#     'spokeswoman',
#     'sort',
#     'minor',
#     'regulatori',
#     'issu',
#     'make',
#     'big',
#     'tim',
#     'johnson',
#     'oblig',
#     'BT',
#     'similar',
#     'compani',
#     'open',
#     'infrastructur',
#     'data',
#     'market',
#     'singl',
#     'effect',
#     'measur',
#     'govern',
#     'creat',
#     'super',
#     'fast',
#     'broadband',
#     'network',
#     'Mr',
#     'hunt',
#     'persuad',
#     'compani',
#     'rutland',
#     'invest',
#     'broadband',
#     'absolut',
#     'part',
#     'process',
#     'We',
#     'level',
#     'play',
#     'field',
#     'make',
#     'easi',
#     'peopl',
#     'lay',
#     'fibr',
#     'BT',
#     'duct',
#     'He',
#     'legisl',
#     'requir',
#     'open',
#     'duct',
#     'electr',
#     'water',
#     'compani'],
#    'date': datetime.datetime(2010, 7, 15, 0, 0),
#    'title': ['broadband', 'britain', 'rollout', 'delay', 'year'],
#    'url': 'http://www.bbc.com/news/technology-10628273'}],
#  [{'category': 'Business',
#    'content': ['sage',
#     'UK',
#     'largest',
#     'softwar',
#     'busi',
#     'appoint',
#     'guy',
#     'berruy',
#     'succeed',
#     'long',
#     'time',
#     'chief',
#     'execut',
#     'paul',
#     'walker',
#     'Mr',
#     'berruy',
#     'charg',
#     'sage',
#     'oper',
#     'mainland',
#     'europ',
#     'asia',
#     'octob',
#     'sage',
#     'specialis',
#     'account',
#     'softwar',
#     'ftse',
#     'compani',
#     'reput',
#     'technolog',
#     'sector',
#     'perform',
#     'Mr',
#     'walker',
#     'chief',
#     'execut',
#     'due',
#     'leav',
#     'sage',
#     'decemb',
#     'guy',
#     'led',
#     'success',
#     'growth',
#     'busi',
#     'europ',
#     'recent',
#     'asia',
#     'sage',
#     'chairman',
#     'anthoni',
#     'hobson',
#     'He',
#     'strong',
#     'track',
#     'record',
#     'profit',
#     'growth',
#     'organ',
#     'success',
#     'acquisit',
#     'integr',
#     'compani',
#     'intern',
#     'candid',
#     'replac',
#     'Mr',
#     'walker',
#     'investor',
#     'sage',
#     'departur',
#     'panmur',
#     'gordon',
#     'analyst',
#     'georg',
#     'O',
#     'connor',
#     'Mr',
#     'berruy',
#     'steep',
#     'sage',
#     'pole',
#     'posit',
#     'sage',
#     'report',
#     'fall',
#     'revenu',
#     'declin',
#     'oper',
#     'profit',
#     'lead',
#     'analyst',
#     'feel',
#     'inject',
#     'fresh',
#     'life',
#     'busi',
#     'domin',
#     'year',
#     'Mr',
#     'walker',
#     'nice',
#     'smooth',
#     'transit',
#     'sage',
#     'wrote',
#     'anthoni',
#     'miller',
#     'technolog',
#     'research',
#     'firm',
#     'techmarketview',
#     'sage',
#     'highli',
#     'disrupt',
#     'transit',
#     'Mr',
#     'berruy',
#     'french',
#     'nation',
#     'train',
#     'engin',
#     'join',
#     'sage',
#     'He',
#     'appoint',
#     'board',
#     'januari'],
#    'date': datetime.datetime(2010, 7, 16, 0, 0),
#    'title': ['sage', 'appoint', 'guy', 'berruy', 'chief', 'execut'],
#    'url': 'http://www.bbc.com/news/business-10660968'},
#   {'category': 'Business',
#    'content': ['mobil',
#     'phone',
#     'maker',
#     'soni',
#     'ericsson',
#     'post',
#     'consecut',
#     'quarterli',
#     'profit',
#     'smartphon',
#     'sale',
#     'world',
#     'biggest',
#     'handset',
#     'maker',
#     'ericsson',
#     'soni',
#     'made',
#     'pre',
#     'tax',
#     'profit',
#     '31m',
#     'euro',
#     'quarter',
#     '7m',
#     '26m',
#     'firm',
#     'lost',
#     '283m',
#     'euro',
#     'quarter',
#     'smartphon',
#     'devic',
#     'PC',
#     'function',
#     'link',
#     'social',
#     'network',
#     'site',
#     'reawaken',
#     'consum',
#     'appetit',
#     'gadget',
#     'compani',
#     'expect',
#     'slight',
#     'market',
#     'growth',
#     'year',
#     'competit',
#     'key',
#     'smartphon',
#     'segment',
#     'intens',
#     'nokia',
#     'world',
#     'biggest',
#     'handset',
#     'maker',
#     'issu',
#     'profit',
#     'warn',
#     'june',
#     'smartphon',
#     'struggl',
#     'appl',
#     'iphon',
#     'soni',
#     'ericsson',
#     'newest',
#     'model',
#     'includ',
#     'xperia',
#     'x10',
#     'vivaz',
#     'smartphon',
#     'xperia',
#     'x10',
#     'mini',
#     'xperia',
#     'x10',
#     'mini',
#     'pro',
#     'compani',
#     'chief',
#     'execut',
#     'bert',
#     'nordberg',
#     'phone',
#     'receiv',
#     'oper',
#     'posit',
#     'long',
#     'term',
#     'growth',
#     'soni',
#     'ericsson',
#     'spent',
#     'past',
#     'year',
#     'cut',
#     'cost',
#     'shed',
#     'staff',
#     'workforc',
#     'period'],
#    'date': datetime.datetime(2010, 7, 16, 0, 0),
#    'title': ['soni', 'ericsson', 'profit', 'boost', 'smartphon'],
#    'url': 'http://www.bbc.com/news/business-10662947'},
#   {'category': 'Business',
#    'content': ['US',
#     'consum',
#     'price',
#     'index',
#     'fell',
#     'consecut',
#     'month',
#     'june',
#     'rais',
#     'fear',
#     'deflat',
#     'price',
#     'fell',
#     'month',
#     'ad',
#     'fall',
#     'april',
#     'labor',
#     'depart',
#     'fall',
#     'energi',
#     'price',
#     'biggest',
#     'contributor',
#     'food',
#     'price',
#     'remain',
#     'unchang',
#     'core',
#     'inflat',
#     'measur',
#     'strip',
#     'volatil',
#     'energi',
#     'food',
#     'price',
#     'economist',
#     'judg',
#     'long',
#     'term',
#     'inflat',
#     'trend',
#     'rose',
#     'US',
#     'feder',
#     'reserv',
#     'pump',
#     'trillion',
#     '780bn',
#     'US',
#     'economi',
#     'promot',
#     'recoveri',
#     'continu',
#     'fall',
#     'price',
#     'add',
#     'pressur',
#     'central',
#     'bank',
#     'unconvent',
#     'measur',
#     'push',
#     'inflat',
#     'posit',
#     'territori',
#     'measur',
#     'includ',
#     'increas',
#     'money',
#     'suppli',
#     'quantit',
#     'eas',
#     'interven',
#     'US',
#     'govern',
#     'bond',
#     'market',
#     'hold',
#     'long',
#     'term',
#     'interest',
#     'rate',
#     'In',
#     'recent',
#     'releas',
#     'minut',
#     'fed',
#     'june',
#     'meet',
#     'policymak',
#     'rais',
#     'action',
#     'year',
#     'economi',
#     'slow'],
#    'date': datetime.datetime(2010, 7, 16, 0, 0),
#    'title': ['US', 'consum', 'price', 'fall', 'month', 'june'],
#    'url': 'http://www.bbc.com/news/business-10662909'},
#   {'category': 'Business',
#    'content': ['microsoft',
#     'founder',
#     'paul',
#     'allen',
#     'commit',
#     'major',
#     'estim',
#     '5bn',
#     '8bn',
#     'fortun',
#     'philanthropi',
#     'death',
#     'Mr',
#     'allen',
#     'fellow',
#     'founder',
#     'bill',
#     'gate',
#     'pledg',
#     'billion',
#     'dollar',
#     'project',
#     'design',
#     'He',
#     'set',
#     'charit',
#     'foundat',
#     'year',
#     'ago',
#     '400m',
#     'He',
#     'person',
#     'donat',
#     '600m',
#     'Mr',
#     'allen',
#     'found',
#     'technolog',
#     'giant',
#     'microsoft',
#     'Mr',
#     'gate',
#     'left',
#     'compani',
#     'announc',
#     'philanthrop',
#     'effort',
#     'continu',
#     'lifetim',
#     'Mr',
#     'allen',
#     '37th',
#     'richest',
#     'man',
#     'world',
#     'forb',
#     'magazin',
#     've',
#     'plan',
#     'year',
#     'major',
#     'estat',
#     'left',
#     'philanthropi',
#     'continu',
#     'work',
#     'foundat',
#     'fund',
#     'profit',
#     'scientif',
#     'research',
#     'announc',
#     'month',
#     'Mr',
#     'gate',
#     'fellow',
#     'billionair',
#     'warren',
#     'buffett',
#     'launch',
#     'campaign',
#     'urg',
#     'richest',
#     'individu',
#     'US',
#     'pledg',
#     'half',
#     'fortun',
#     'chariti',
#     'Mr',
#     'allen',
#     'left',
#     'microsoft',
#     'diagnos',
#     'blood',
#     'cancer',
#     'hodgkin',
#     'diseas',
#     'He',
#     'success',
#     'beat',
#     'ill',
#     'success',
#     'ventur',
#     'capitalist',
#     'media',
#     'commun',
#     'invest',
#     'firm',
#     'vulcan',
#     'In',
#     'bitter',
#     'ironi',
#     'Mr',
#     'allen',
#     'sister',
#     'reveal',
#     'entrepreneur',
#     'recent',
#     'develop',
#     'form',
#     'blood',
#     'cancer',
#     'hodgkin',
#     'lymphoma'],
#    'date': datetime.datetime(2010, 7, 16, 0, 0),
#    'title': ['microsoft', 'founder', 'commit', 'billion', 'philanthropi'],
#    'url': 'http://www.bbc.com/news/business-10655764'},
#   {'category': 'Technology',
#    'content': ['appl',
#     'offer',
#     'free',
#     'case',
#     'owner',
#     'iphon',
#     'appl',
#     'boss',
#     'steve',
#     'job',
#     'unveil',
#     'offer',
#     'press',
#     'confer',
#     'call',
#     'tackl',
#     'ongo',
#     'specul',
#     'iphon',
#     'antenna',
#     'problem',
#     'case',
#     'overcom',
#     'wide',
#     'report',
#     'issu',
#     'phone',
#     'signal',
#     'strength',
#     'drain',
#     'phone',
#     'held',
#     'declar',
#     'We',
#     'perfect',
#     'Mr',
#     'job',
#     'recept',
#     'problem',
#     'endem',
#     'smartphon',
#     'industri',
#     'To',
#     'free',
#     'case',
#     'owner',
#     'appli',
#     'appl',
#     'websit',
#     'juli',
#     'Mr',
#     'job',
#     'appl',
#     'make',
#     'owner',
#     'phone',
#     'sourc',
#     'suppli',
#     'offer',
#     'rang',
#     'case',
#     'base',
#     'retail',
#     'price',
#     'iphon',
#     'case',
#     'suppli',
#     'million',
#     'custom',
#     'cost',
#     'appl',
#     '180m',
#     '118m',
#     'appl',
#     'offer',
#     'free',
#     'case',
#     'phone',
#     'purchas',
#     'septemb',
#     'Mr',
#     'job',
#     'extend',
#     'offer',
#     'iphon',
#     'user',
#     'full',
#     'refund',
#     'day',
#     'unhappi',
#     'handset',
#     'perform',
#     'van',
#     'baker',
#     'research',
#     'vice',
#     'presid',
#     'gartner',
#     'told',
#     'bbc',
#     'buzz',
#     'louder',
#     'louder',
#     'louder',
#     'evid',
#     'mount',
#     'couldn',
#     'brian',
#     'marshal',
#     'manag',
#     'director',
#     'gleacher',
#     'compani',
#     'neg',
#     'headlin',
#     'hurt',
#     'appl',
#     'marketplac',
#     'action',
#     'blown',
#     'proport',
#     'media',
#     'firestorm',
#     'appl',
#     'call',
#     'press',
#     'confer',
#     'case',
#     'offer',
#     'made',
#     'respons',
#     'ongo',
#     'specul',
#     'antenna',
#     'issu',
#     'problem',
#     'thought',
#     'steel',
#     'case',
#     'phone',
#     'hous',
#     'phone',
#     'antenna',
#     'hold',
#     'phone',
#     'lower',
#     'left',
#     'bridg',
#     'gap',
#     'antenna',
#     'deplet',
#     'signal',
#     'put',
#     'case',
#     'bumper',
#     'phone',
#     'stop',
#     'gap',
#     'bridg',
#     'open',
#     'confer',
#     'Mr',
#     'job',
#     'drop',
#     'signal',
#     'strength',
#     'problem',
#     'uniqu',
#     'iphon',
#     'blown',
#     'proport',
#     'incred',
#     'appl',
#     'close',
#     'issu',
#     'report',
#     'problem',
#     'surfac',
#     'week',
#     'ago',
#     'video',
#     'compar',
#     'iphon',
#     'signal',
#     'drop',
#     'smartphon',
#     'blackberri',
#     'bold',
#     'air',
#     'Mr',
#     'job',
#     'confer',
#     'He',
#     'reflect',
#     'life',
#     'smartphon',
#     'world',
#     'present',
#     'challeng',
#     'industri',
#     'Mr',
#     'job',
#     'design',
#     'iphon',
#     'gap',
#     'separ',
#     'section',
#     'antenna',
#     'contribut',
#     'problem',
#     'sublimin',
#     'encourag',
#     'peopl',
#     'touch',
#     'spot',
#     'In',
#     'firm',
#     'defenc',
#     'cite',
#     'figur',
#     'appl',
#     'care',
#     'servic',
#     'arm',
#     'show',
#     'iphon',
#     'user',
#     'complain',
#     'compani',
#     'issu',
#     'histor',
#     'larg',
#     'number',
#     'doesn',
#     'jibe',
#     'read',
#     'problem',
#     'number',
#     'phone',
#     'return',
#     'appl',
#     '3g',
#     'model',
#     'back',
#     'shop',
#     'owner',
#     'Mr',
#     'job',
#     'share',
#     'data',
#     'number',
#     'call',
#     'iphone4',
#     'drop',
#     'compar',
#     '3g',
#     'reveal',
#     'iphon',
#     'drop',
#     'call',
#     'hundr',
#     'predecessor',
#     'He',
#     'specul',
#     'peopl',
#     '3g',
#     'case',
#     'By',
#     'contrast',
#     'iphone4',
#     'leav',
#     'appl',
#     'store',
#     'case',
#     'technolog',
#     'report',
#     'maggi',
#     'shiel',
#     'attend',
#     'confer',
#     'bbc',
#     'sterl',
#     'perform',
#     'Mr',
#     'job',
#     'steve',
#     'job',
#     'publicli',
#     'apologis',
#     'custom',
#     'problem',
#     'amaz',
#     'hear',
#     'It',
#     'didn',
#     'min',
#     'event',
#     'clear',
#     'critic',
#     'person',
#     'constantli',
#     'underscor',
#     'hard',
#     'appl',
#     'work',
#     'resolv',
#     'problem',
#     'swing',
#     'fenc',
#     'defend',
#     'phone',
#     'hilt'],
#    'date': datetime.datetime(2010, 7, 16, 0, 0),
#    'title': ['appl', 'offer', 'free', 'iphon', 'case'],
#    'url': 'http://www.bbc.com/news/technology-10665424'},
#   {'category': 'Technology',
#    'content': ['A',
#     'wireless',
#     'headset',
#     'interpret',
#     'brain',
#     'wave',
#     'control',
#     'video',
#     'game',
#     'onscreen',
#     'action',
#     'shown',
#     'tech',
#     'confer',
#     'emotiv',
#     'epoc',
#     'claim',
#     'neural',
#     'headset',
#     'aim',
#     'consum',
#     'system',
#     'sale',
#     'centuri',
#     'medic',
#     'techniqu',
#     'read',
#     'electr',
#     'signal',
#     'brain',
#     'technolog',
#     'seri',
#     'algorithm',
#     'convert',
#     'onscreen',
#     'movement',
#     'game',
#     'firm',
#     'technolog',
#     'interact',
#     'comput',
#     'mobil',
#     'phone',
#     'control',
#     'smart',
#     'home',
#     'medic',
#     'devic',
#     'Up',
#     'commun',
#     'machin',
#     'limit',
#     'tan',
#     'Le',
#     'emotiv',
#     'ted',
#     'global',
#     'technolog',
#     'entertain',
#     'design',
#     'confer',
#     'oxford',
#     'headset',
#     'invas',
#     'electroencephalographi',
#     'eeg',
#     'techniqu',
#     'commonli',
#     'diagnos',
#     'monitor',
#     'epilepsi',
#     'medic',
#     'headset',
#     'cost',
#     'thousand',
#     'pound',
#     'specialist',
#     'staff',
#     'epoc',
#     'headset',
#     'comparison',
#     'cost',
#     'standard',
#     'laptop',
#     'It',
#     'consist',
#     'sensor',
#     'read',
#     'electr',
#     'signal',
#     'billion',
#     'nerv',
#     'cell',
#     'neuron',
#     'brain',
#     'transmit',
#     'wirelessli',
#     'laptop',
#     'train',
#     'system',
#     'recognis',
#     'specif',
#     'teach',
#     'devic',
#     'simpl',
#     'applic',
#     'matter',
#     'minut',
#     'demonstr',
#     'ted',
#     'Ms',
#     'Le',
#     'show',
#     'make',
#     'cube',
#     'screen',
#     'rotat',
#     'move',
#     'thought',
#     'headset',
#     'releas',
#     'larg',
#     'research',
#     'univers',
#     'compani',
#     'interest',
#     'build',
#     'applic',
#     'gamer',
#     'Ms',
#     'Le',
#     'ten',
#     'thousand',
#     'sold',
#     'mass',
#     'market',
#     'devic',
#     'point',
#     'juri',
#     'technolog',
#     'reach',
#     'ubiqu',
#     'told',
#     'bbc',
#     'We',
#     'don',
#     'flood',
#     'market',
#     'devic',
#     'readi',
#     'focu',
#     'support',
#     'develop',
#     'research',
#     'commun',
#     'bring',
#     'applic',
#     'develop',
#     'devic',
#     'game',
#     'mind',
#     'control',
#     'tetri',
#     'softwar',
#     'sort',
#     'photo',
#     'build',
#     'control',
#     'medic',
#     'devic',
#     'prosthet',
#     'wheel',
#     'chair',
#     'Ms',
#     'Le',
#     'firm',
#     'merg',
#     'technolog',
#     'devic',
#     'mobil',
#     'phone',
#     'press',
#     'seri',
#     'button',
#     'call',
#     'person',
#     'firm',
#     'explor',
#     'neural',
#     'market',
#     'techniqu',
#     'advertis',
#     'firm',
#     'potenti',
#     'buyer',
#     'react',
#     'favour',
#     'ad',
#     'We',
#     'direct',
#     'biosign',
#     'object',
#     'firm',
#     'work',
#     'refin',
#     'technolog',
#     'oper',
#     'system',
#     'mac',
#     'OS',
#     'X',
#     'linux',
#     'Ms',
#     'Le',
#     'epoc',
#     'sight',
#     'set',
#     'refin',
#     'technolog',
#     'make',
#     'capabl',
#     'pick',
#     'process',
#     'subtl',
#     'signal',
#     'make',
#     'accept',
#     'everyday',
#     'greatest',
#     'challeng',
#     'comput',
#     'power',
#     'challeng',
#     'optimis',
#     'set',
#     'algorithm',
#     'train',
#     'PC',
#     'minut',
#     'experi',
#     'technolog',
#     'If',
#     'build',
#     'brain',
#     'technolog',
#     'month',
#     'train',
#     'build',
#     'lot',
#     'control',
#     'time',
#     'comput',
#     'inevit',
#     'power',
#     'crunch',
#     'complex',
#     'signal',
#     'firm',
#     'introduc',
#     'element',
#     'kinet',
#     'charg',
#     'devic',
#     'power',
#     'user',
#     'movement',
#     'reli',
#     'batteri',
#     'In',
#     'addit',
#     'firm',
#     'shrink',
#     'technolog',
#     'specif',
#     'applic',
#     'mobil',
#     'phone',
#     'We',
#     'begin',
#     'journey',
#     'ted',
#     'global',
#     'run',
#     'juli',
#     'oxford',
#     'UK'],
#    'date': datetime.datetime(2010, 7, 16, 0, 0),
#    'title': ['brain', 'video', 'game', 'control'],
#    'url': 'http://www.bbc.com/news/technology-10647555'}],
#  [{'category': 'Science & Environment',
#    'content': ['UK',
#     'risk',
#     'left',
#     'low',
#     'carbon',
#     'futur',
#     'govern',
#     'spend',
#     'protect',
#     'increas',
#     'advis',
#     'committe',
#     'climat',
#     'ccc',
#     'report',
#     'day',
#     'coalit',
#     'announc',
#     '34m',
#     'cut',
#     'invest',
#     'offshor',
#     'wind',
#     'geotherm',
#     'biofuel',
#     'committe',
#     'warn',
#     'countri',
#     'spend',
#     'conserv',
#     'MP',
#     'tim',
#     'yeo',
#     'issu',
#     'pamphlet',
#     'urg',
#     'radic',
#     'move',
#     'privatis',
#     'motorway',
#     'chairman',
#     'climat',
#     'energi',
#     'select',
#     'committe',
#     'work',
#     'low',
#     'carbon',
#     'economi',
#     'essenti',
#     'britain',
#     'futur',
#     'prosper',
#     'committe',
#     'climat',
#     'charg',
#     'advis',
#     'govern',
#     'meet',
#     'medium',
#     'long',
#     'term',
#     'target',
#     'reduc',
#     'greenhous',
#     'ga',
#     'emiss',
#     'goal',
#     'cut',
#     'emiss',
#     'maintain',
#     'increas',
#     'invest',
#     'low',
#     'carbon',
#     'technolog',
#     'essenti',
#     'target',
#     'hit',
#     'week',
#     'depart',
#     'energi',
#     'climat',
#     'decc',
#     'announc',
#     'cut',
#     'grant',
#     'programm',
#     'part',
#     'cost',
#     'cut',
#     'drive',
#     'whitehal',
#     'unwelcom',
#     'move',
#     'wrong',
#     'direct',
#     'ccc',
#     'chief',
#     'execut',
#     'david',
#     'kennedi',
#     'specif',
# ...
#     'EA',
#     'damag',
#     'limit',
#     'compani',
#     'eventu',
#     'releas',
#     'statement',
#     'softwar',
#     'access',
#     'file',
#     'directli',
#     'relat',
#     'game',
#     'captur',
#     'person',
#     'data',
#     'cooki',
#     'account',
#     'login',
#     'detail',
#     'surf',
#     'histori',
#     'today',
#     'advert',
#     'benign',
#     'billboard',
#     'graphic',
#     'game',
#     'advert',
#     'bonu',
#     'game',
#     'industri',
#     'secondari',
#     'busi',
#     'model',
#     'Mr',
#     'hard',
#     'roll',
#     'nice',
#     'increment',
#     'expect',
#     'grow',
#     'signific',
#     'present',
#     'tiga',
#     'report',
#     'sound',
#     'note',
#     'warn',
#     'UK',
#     'game',
#     'develop',
#     'signific',
#     'disadvantag',
#     'due',
#     'lack',
#     'tax',
#     'break',
#     'offer',
#     'govern',
#     'canada',
#     'franc',
#     'canada',
#     'offer',
#     'signific',
#     'tax',
#     'break',
#     'case',
#     'encourag',
#     'growth',
#     'countri',
#     'game',
#     'sector',
#     'UK',
#     'chancellor',
#     'georg',
#     'osborn',
#     'rule',
#     'tax',
#     'break',
#     'emerg',
#     'budget',
#     'cultur',
#     'minist',
#     'Ed',
#     'vaizey',
#     'door',
#     'open',
#     'negoti',
#     'subject'],
#    'date': datetime.datetime(2010, 8, 11, 0, 0),
#    'title': ['UK', 'game', 'develop', 'turn', 'iphon'],
#    'url': 'http://www.bbc.com/news/technology-10937388'},
#   {'category': 'Health',
#    'content': ['A',
#     'superbug',
#     'resist',
#     'power',
#     'antibiot',
#     'enter',
#     'UK',
#     'hospit',
#     'expert',
#     'warn',
#     'bacteria',
#     'make',
#     'enzym',
#     'call',
#     'ndm',
#     'travel',
#     'back',
#     'nh',
#     'patient',
#     'abroad',
#     'countri',
#     'india',
#     'pakistan',
#     'treatment',
#     'cosmet',
#     'surgeri',
#     'case',
#     'identifi',
#     'UK',
#     'scientist',
#     'fear',
#     'global',
#     'tight',
#     'surveil',
#     'drug',
#     'lancet',
#     'infecti',
#     'diseas',
#     'ndm',
#     'exist',
#     'insid',
#     'bacteria',
#     'E',
#     'coli',
#     'make',
#     'resist',
#     'power',
#     'group',
#     'antibiot',
#     'carbapenem',
#     'gener',
#     'reserv',
#     'emerg',
#     'combat',
#     'hard',
#     'treat',
#     'infect',
#     'multi',
#     'resist',
#     'bacteria',
#     'expert',
#     'fear',
#     'ndm',
#     'jump',
#     'strain',
#     'bacteria',
#     'resist',
#     'antibiot',
#     'ultim',
#     'produc',
#     'danger',
#     'infect',
#     'spread',
#     'rapidli',
#     'person',
#     'person',
#     'imposs',
#     'treat',
#     'At',
#     'ndm',
#     'infect',
#     'research',
#     'analys',
#     'resist',
#     'antibiot',
#     'similar',
#     'infect',
#     'US',
#     'canada',
#     'australia',
#     'netherland',
#     'intern',
#     'research',
#     'ndm',
#     'major',
#     'global',
#     'health',
#     'problem',
#     'infect',
#     'pass',
#     'patient',
#     'patient',
#     'UK',
#     'hospit',
#     'stop',
#     'ndm',
#     'research',
#     'rapidli',
#     'identifi',
#     'isol',
#     'hospit',
#     'patient',
#     'infect',
#     'infect',
#     'control',
#     'measur',
#     'disinfect',
#     'hospit',
#     'equip',
#     'doctor',
#     'nurs',
#     'wash',
#     'hand',
#     'antibacteri',
#     'soap',
#     'stop',
#     'spread',
#     'bacteria',
#     'carri',
#     'ndm',
#     'treatabl',
#     'combin',
#     'antibiot',
#     'potenti',
#     'ndm',
#     'endem',
#     'worldwid',
#     'clear',
#     'frighten',
#     'research',
#     'lancet',
#     'infecti',
#     'diseas',
#     'paper',
#     'research',
#     'carri',
#     'expert',
#     'cardiff',
#     'univers',
#     'health',
#     'protect',
#     'agenc',
#     'intern',
#     'colleagu',
#     'Dr',
#     'david',
#     'livermor',
#     'research',
#     'work',
#     'UK',
#     'health',
#     'protect',
#     'agenc',
#     'hpa',
#     'number',
#     'small',
#     'cluster',
#     'UK',
#     'greater',
#     'number',
#     'case',
#     'travel',
#     'hospit',
#     'treatment',
#     'indian',
#     'subcontin',
#     'type',
#     'resist',
#     'widespread',
#     'fear',
#     'strain',
#     'bacteria',
#     'good',
#     'transmit',
#     'patient',
#     'He',
#     'threat',
#     'global',
#     'public',
#     'health',
#     'problem',
#     'suitabl',
#     'antibiot',
#     'develop',
#     'effect',
#     'ndm',
#     'depart',
#     'health',
#     'put',
#     'alert',
#     'issu',
#     'We',
#     'issu',
#     'alert',
#     'sparingli',
#     'disturb',
#     'resist',
#     'nation',
#     'resist',
#     'alert',
#     'hpa',
#     'note',
#     'increas',
#     'number',
#     'case',
#     'fatal',
#     'emerg',
#     'UK',
#     'lancet',
#     'studi',
#     'back',
#     'ndm',
#     'case',
#     'refer',
#     'hpa',
#     'hospit',
#     'scatter',
#     'UK',
#     'At',
#     'patient',
#     'studi',
#     'histori',
#     'travel',
#     'india',
#     'pakistan',
#     'past',
#     'year',
#     'admit',
#     'hospit',
#     'countri',
#     'cosmet',
#     'surgeri',
#     'patient',
#     'infect',
#     'mild',
#     'ill',
#     'blood',
#     'poison',
#     'A',
#     'depart',
#     'health',
#     'spokeswoman',
#     'We',
#     'work',
#     'hpa',
#     'issu',
#     'hospit',
#     'ensur',
#     'continu',
#     'good',
#     'infect',
#     'control',
#     'prevent',
#     'spread',
#     'patient',
#     'recent',
#     'treat',
#     'abroad',
#     'send',
#     'sampl',
#     'hpa',
#     'test',
#     'So',
#     'small',
#     'number',
#     'case',
#     'UK',
#     'hospit',
#     'patient',
#     'hpa',
#     'continu',
#     'monitor',
#     'situat',
#     'investig',
#     'encourag',
#     'develop',
#     'antibiot',
#     'european',
#     'colleagu',
#     'welsh',
#     'assembl',
#     'govern',
#     'fulli',
#     'report',
#     'nh',
#     'wale',
#     'deal',
#     'multi',
#     'resist',
#     'bacteria',
#     'standard',
#     'microbiolog',
#     'approach',
#     'deal',
#     'bacteria',
#     'similar',
#     'spokesperson'],
#    'date': datetime.datetime(2010, 8, 11, 0, 0),
#    'title': ['superbug', 'found', 'UK', 'hospit'],
#    'url': 'http://www.bbc.com/news/health-10925411'}],
#  [{'category': 'Health',
#    'content': ['breast',
#     'cancer',
#     'death',
#     'fallen',
#     'UK',
#     'mortal',
#     'rate',
#     'diseas',
#     'continu',
#     'highest',
#     'europ',
#     'studi',
#     'show',
#     'review',
#     'countri',
#     'led',
#     'french',
#     'research',
#     'show',
#     'UK',
#     'rate',
#     'drop',
#     'care',
#     'speedier',
#     'diagnosi',
#     'number',
#     'UK',
#     'death',
#     'breast',
#     'cancer',
#     'fell',
#     'equival',
#     'death',
#     'year',
#     'govern',
#     'progress',
#     'earlier',
#     'diagnosi',
#     'research',
#     'rate',
#     'breast',
#     'cancer',
#     'highlight',
#     'death',
#     'compar',
#     'british',
#     'medic',
#     'journal',
#     'report',
#     'mortal',
#     'rate',
#     'countri',
#     'fell',
#     'death',
#     'spain',
#     'lowest',
#     'rate',
#     'UK',
#     'comparison',
#     'fell',
#     'progress',
#     'UK',
#     'lag',
#     'countri',
#     'romania',
#     'estonia',
#     'germani',
#     'franc',
#     'research',
#     'franc',
#     'intern',
#     'prevent',
#     'research',
#     'institut',
#     'fall',
#     'countri',
#     'attribut',
#     'faster',
#     'diagnosi',
#     'qualiti',
#     'care',
#     'admit',
#     'variat',
#     'perform',
#     'death',
#     'record',
#     'expect',
#     'UK',
#     'death',
#     'rate',
#     'continu',
#     'improv',
#     'final',
#     'reach',
#     'top',
#     'perform',
#     'ad',
#     'lifestyl',
#     'hamper',
#     'progress',
#     'extent',
#     'factor',
#     'drink',
#     'obes',
#     'age',
#     'woman',
#     'children',
#     'influenc',
#     'likelihood',
#     'breast',
#     'cancer',
#     'develop',
#     'hilari',
#     'tovey',
#     'cancer',
#     'research',
#     'UK',
#     'polici',
#     'manag',
#     'hail',
#     'great',
#     'progress',
#     'made',
#     'UK',
#     'greater',
#     'decreas',
#     'number',
#     'women',
#     'die',
#     'breast',
#     'cancer',
#     'european',
#     'countri',
#     'period',
#     'partli',
#     'death',
#     'rate',
#     'high',
#     'breast',
#     'cancer',
#     'patient',
#     'marilyn',
#     'morri',
#     'told',
#     'bbc',
#     'report',
#     'find',
#     'encourag',
#     'peopl',
#     'fight',
#     'diseas',
#     'It',
#     'terrif',
#     'boost',
#     'diagnos',
#     'breast',
#     'cancer',
#     'thing',
#     'recent',
#     'monthli',
#     'progress',
#     'made',
#     'peopl',
#     'news',
#     'find',
#     'chime',
#     'research',
#     'cancer',
#     'surviv',
#     'rate',
#     'measur',
#     'health',
#     'servic',
#     'perform',
#     'number',
#     'signific',
#     'breast',
#     'cancer',
#     'care',
#     'includ',
#     'introduct',
#     'screen',
#     'programm',
#     'recent',
#     'host',
#     'wait',
#     'time',
#     'target',
#     'A',
#     'spokesman',
#     'depart',
#     'health',
#     'rapid',
#     'drop',
#     'breast',
#     'cancer',
#     'mortal',
#     'rate',
#     'show',
#     'nh',
#     'made',
#     'treatment',
#     'screen',
#     'access',
#     'drug',
#     'made',
#     'england',
#     'breast',
#     'cancer',
#     'mortal',
#     'lag',
#     'countri',
#     'focus',
#     'improv',
#     'outcom',
#     'achiev',
#     'earlier',
#     'diagnosi'],
#    'date': datetime.datetime(2010, 8, 12, 0, 0),
#    'title': ['breast', 'cancer', 'death', 'fall', 'UK'],
#    'url': 'http://www.bbc.com/news/health-10944826'},
#   {'category': 'Science & Environment',
#    'content': ['astronom',
#     'found',
#     '100km',
#     'diamet',
#     'trojan',
#     'asteroid',
#     'neptun',
#     'trojan',
#     'type',
#     'asteroid',
#     'found',
#     'space',
#     'graveyard',
#     'shed',
#     'light',
#     'earli',
#     'solar',
#     'system',
#     'scientist',
#     'similar',
#     'object',
#     'await',
#     'discoveri',
#     'area',
#     'asteroid',
#     'discov',
#     'Dr',
#     'scott',
#     'sheppard',
#     'carnegi',
#     'institut',
#     'Dr',
#     'chadwick',
#     'trujillo',
#     'gemini',
#     'observatori',
#     'hawaii',
#     'find',
#     'publish',
#     'journal',
#     'scienc',
#     'space',
#     'graveyardtrojan',
#     'asteroid',
#     'orbit',
#     'plane',
#     'planet',
#     'don',
#     'collid',
#     'occur',
#     'dead',
#     'zone',
#     'gravit',
#     'forc',
#     'asteroid',
#     'orbit',
#     'precis',
#     'speed',
#     'planet',
#     'lagrangian',
#     'point',
#     'dead',
#     'zone',
#     'call',
#     'occur',
#     'degre',
#     'ahead',
#     'planet',
#     'graveyard',
#     'space',
#     'junk',
#     'frozen',
#     'time',
#     'format',
#     'solar',
#     'system',
#     'trojan',
#     'asteroid',
#     'larger',
#     '1km',
#     'found',
#     'date',
#     'orbit',
#     'jupit',
#     'newli',
#     'discov',
#     'trojan',
#     'neptun',
#     'asteroid',
#     '2008lc18',
#     'occur',
#     'area',
#     'sky',
#     'milki',
#     'galaxi',
#     'bright',
#     'Dr',
#     'sheppard',
#     'team',
#     'devis',
#     'uniqu',
#     'observ',
#     'strategi',
#     'spot',
#     'asteroid',
#     'bright',
#     'star',
#     'field',
#     'interstellar',
#     'dust',
#     'mask',
#     'star',
#     'light',
#     '100km',
#     'asteroid',
#     'visibl',
#     'breakthrough',
#     'made',
#     '2m',
#     'japanes',
#     'subaru',
#     'telescop',
#     'hawaii',
#     'scientist',
#     'similar',
#     'size',
#     'object',
#     'cloud',
#     'eventu',
#     'trojan',
#     'cloud',
#     'neptun',
#     'prove',
#     'big',
#     'orbit',
#     'jupit',
#     'professor',
#     'alan',
#     'fitzsimmon',
#     'queen',
#     'univers',
#     'belfast',
#     'expert',
#     'asteroid',
#     'incred',
#     'excit',
#     'discoveri',
#     'It',
#     'import',
#     'clue',
#     'unravel',
#     'earli',
#     'evolut',
#     'solar',
#     'system'],
#    'date': datetime.datetime(2010, 8, 12, 0, 0),
#    'title': ['trojan', 'asteroid', 'found', 'neptun', 'dead', 'zone'],
#    'url': 'http://www.bbc.com/news/science-environment-10954453'},
#   {'category': 'Technology',
#    'content': ['A',
#     'major',
#     'american',
#     'govern',
#     'plan',
#     'deliv',
#     'high',
#     'speed',
#     'internet',
#     'connect',
#     'citizen',
#     'import',
#     'embark',
#     'pew',
#     'internet',
#     'project',
#     'survey',
#     'respond',
#     'felt',
#     'felt',
#     'issu',
#     'top',
#     'prioriti',
#     'surpris',
#     'outcom',
#     'amid',
#     'fierc',
#     'debat',
#     'broadband',
#     'We',
#     'econom',
#     'hard',
#     'time',
#     'govern',
#     'spend',
#     'hard',
#     'sell',
#     'report',
#     'author',
#     'aaron',
#     'smith',
#     'recess',
#     'sentiment',
#     'issu',
#     'import',
#     'It',
#     'user',
#     'nervou',
#     'govern',
#     'promot',
#     'technolog',
#     'don',
#     'unsur',
#     'offer',
#     'clear',
#     'benefit',
#     'Mr',
#     'smith',
#     'told',
#     'bbc',
#     'public',
#     'interest',
#     'group',
#     'public',
#     'knowledg',
#     'vocal',
#     'support',
#     'govern',
#     'broadband',
#     'aim',
#     'figur',
#     'worri',
#     'agre',
#     'larg',
#     'part',
#     'peopl',
#     'money',
#     'spent',
#     'recoveri',
#     'effort',
#     'basic',
#     'servic',
#     'nation',
#     'defenc',
#     'couch',
#     'thought',
#     'luxuri',
#     'group',
#     'deputi',
#     'legal',
#     'director',
#     'sherwin',
#     'siy',
#     'build',
#     'broadband',
#     'contribut',
#     'thing',
#     'centuri',
#     'peopl',
#     'didn',
#     'recognis',
#     'benefit',
#     'electrif',
#     'simpli',
#     'fine',
#     'It',
#     'US',
#     'regul',
#     'report',
#     'undermin',
#     'administr',
#     'effort',
#     'point',
#     'educ',
#     'import',
#     'broadband',
#     'job',
#     'health',
#     'educ',
#     'barrier',
#     'broadband',
#     'adopt',
#     'america',
#     'jen',
#     'howard',
#     'spokeswoman',
#     'feder',
#     'commun',
#     'commiss',
#     'fcc',
#     'broadband',
#     'plan',
#     'lay',
#     'strategi',
#     'improv',
#     'digit',
#     'literaci',
#     'ensur',
#     'american',
#     'full',
#     'advantag',
#     'benefit',
#     'broadband',
#     'obama',
#     'administr',
#     'dedic',
#     'billion',
#     'stimulu',
#     'money',
#     'broadband',
#     'grant',
#     'fast',
#     'access',
#     'internet',
#     'essenti',
#     'encourag',
#     'innov',
#     'economi',
#     'grow',
#     'promis',
#     'signsth',
#     'studi',
#     'question',
#     'american',
#     'adult',
#     'found',
#     'broadband',
#     'adopt',
#     'slow',
#     'dramat',
#     'year',
#     'penetr',
#     'present',
#     'research',
#     'note',
#     'mark',
#     'record',
#     'year',
#     'measur',
#     'comfort',
#     'result',
#     'african',
#     'american',
#     'commun',
#     'broadband',
#     'connect',
#     'home',
#     'compar',
#     'import',
#     'stori',
#     'talk',
#     'digit',
#     'divid',
#     'issu',
#     'report',
#     'Mr',
#     'smith',
#     'It',
#     'year',
#     'african',
#     'american',
#     'growth',
#     'Mr',
#     'smith',
#     'note',
#     'fact',
#     'sector',
#     'popul',
#     'start',
#     'smaller',
#     'base',
#     'user',
#     'mobil',
#     'phone',
#     'mobil',
#     'web',
#     'social',
#     'media',
#     'app',
#     'vibrant',
#     'competit',
#     'In',
#     'recent',
#     'week',
#     'govern',
#     'broadband',
#     'plan',
#     'subject',
#     'heat',
#     'debat',
#     'principl',
#     'net',
#     'neutral',
#     'lynch',
#     'pin',
#     'initi',
#     'net',
#     'neutral',
#     'principl',
#     'web',
#     'data',
#     'treat',
#     'equal',
#     'traffic',
#     'prioriti',
#     'network',
#     'week',
#     'fcc',
#     'halt',
#     'close',
#     'door',
#     'meet',
#     'servic',
#     'internet',
#     'compani',
#     'find',
#     'consensu',
#     'issu',
#     'week',
#     'search',
#     'giant',
#     'googl',
#     'telecom',
#     'titan',
#     'verizon',
#     'unveil',
#     'suggest',
#     'resolv',
#     'log',
#     'jam',
#     'It',
#     'torrent',
#     'critic',
#     'suggest',
#     'fix',
#     'line',
#     'broadband',
#     'mobil',
#     'broadband',
#     'treat',
#     'public',
#     'interest',
#     'consum',
#     'group',
#     'slate',
#     'propos',
#     'social',
#     'network',
#     'site',
#     'facebook',
#     'biggest',
#     'compani',
#     'public',
#     'denunci',
#     'facebook',
#     'continu',
#     'support',
#     'principl',
#     'net',
#     'neutral',
#     'landlin',
#     'wireless',
#     'network',
#     'compani',
#     'statement',
#     'preserv',
#     'open',
#     'internet',
#     'access',
#     'innov',
#     'size',
#     'wealth',
#     'promot',
#     'vibrant',
#     'competit',
#     'marketplac',
#     'consum',
#     'ultim',
#     'control',
#     'content',
#     'servic',
#     'deliv',
#     'internet',
#     'connect'],
#    'date': datetime.datetime(2010, 8, 12, 0, 0),
#    'title': ['US', 'broadband', 'plan', 'prioriti', 'find', 'survey'],
#    'url': 'http://www.bbc.com/news/technology-10948087'}]]
